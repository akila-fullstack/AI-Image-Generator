# %% [markdown]
# <a href="https://colab.research.google.com/github/akila-fullstack/AI-Image-Generator/blob/main/image_generator_by_Akila.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision diffusers pillow

# %%
from diffusers import StableDiffusionPipeline
import torch
from PIL import Image
from IPython.display import display


model = StableDiffusionPipeline.from_pretrained('CompVis/stable-diffusion-v1-4', torch_dtype=torch.float16)
model.to("cuda" if torch.cuda.is_available() else "cpu")

prompt = "a cockroach riding a motorbike"
with torch.no_grad():
    image = model(prompt).images[0]

display(image)
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
